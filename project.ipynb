# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("vehicles.csv")

# %%
data.head()
# Out:
#            id                                                url  \
# 0  7184791621  https://duluth.craigslist.org/ctd/d/duluth-200...
# 1  7184773187  https://duluth.craigslist.org/cto/d/saginaw-20...
# 2  7193375964  https://newhaven.craigslist.org/cto/d/stratfor...
# 3  7195108810  https://albuquerque.craigslist.org/cto/d/albuq...
# 4  7184712241  https://duluth.craigslist.org/ctd/d/rush-city-...
#
#               region                          region_url  price    year  \
# 0  duluth / superior       https://duluth.craigslist.org   6995  2000.0
# 1  duluth / superior       https://duluth.craigslist.org   8750  2013.0
# 2          new haven     https://newhaven.craigslist.org  10900  2013.0
# 3        albuquerque  https://albuquerque.craigslist.org  12500  2003.0
# 4  duluth / superior       https://duluth.craigslist.org  16995  2007.0
#
#   manufacturer                  model  condition    cylinders  ... drive  \
# ...

# %%
data = data.drop(columns=["url", "region_url","image_url",'description','county', 'state', 'lat', 'long', 'paint_color', 'size', 'drive', 'type'])

# %%
data.columns
# Out:
# Index(['id', 'region', 'price', 'year', 'manufacturer', 'model', 'condition',
#        'cylinders', 'fuel', 'odometer', 'title_status', 'transmission', 'vin'],
#       dtype='object')

# %%
d = []
for guy in data['region']:
    d.append(guy)
print(set(d))
# Out:
# {'san diego', 'kalispell', 'valdosta', 'victoria', 'birmingham', 'fort wayne', 'southern illinois', 'grand rapids', 'delaware', 'binghamton', 'eastern CT', 'bismarck', 'statesboro', 'susanville', 'kirksville', 'grand forks', 'waterloo / cedar falls', 'joplin', 'yakima', 'auburn', "spokane / coeur d'alene", 'lehigh valley', 'southern maryland', 'pierre / central SD', 'pensacola', 'lansing', 'ocala', 'battle creek', 'SF bay area', 'eastern CO', 'boise', 'columbus', 'southeast KS', 'tuscarawas co', 'santa barbara', 'east idaho', 'oregon coast', 'clarksville', 'fredericksburg', 'south dakota', 'deep east texas', 'northwest CT', 'st louis', 'sandusky', 'kalamazoo', 'waco', 'memphis', 'southwest MN', 'helena', 'asheville', 'manhattan', 'boulder', 'phoenix', 'wichita', 'rhode island', 'bowling green', 'bemidji', 'tyler / east TX', 'san antonio', 'ogden-clearfield', 'harrisonburg', 'flint', 'appleton-oshkosh-FDL', 'lake charles', 'st joseph', 'la crosse', 'monroe', 'medford-ashland', 'st aug
# ...
